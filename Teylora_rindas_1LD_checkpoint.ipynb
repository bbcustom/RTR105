# %%
#_*_ coding: utf-8 -*-
from math import exp

def mans_exp(x):
    k = 0
    a = (-1)**k*x**(2*k)/(1)
    S = a
    print("a0 = %6.2f S0 = %6.2f"%(a,S))

    while k < 500:
        k = k + 1
        R = -1*x**2/k
        a = a * R
        S = S + a
        if  k == 499:
            print("a%d = %6.2f S%d = %6.2f"%(k,a,k,S))
        elif k == 500:
            print("a%d = %6.2f S%d = %6.2f"%(k,a,k,S))
    
    
    return S

print("exp(-x*x) aprekinasana: ")
x = float(input("Lietotāj, lūdzu ievadi skaitli argumentu (x): "))
y = exp(-x*x)
print("exp(-x*x) (%.2f) = %6.2f"%(x,y))

yy = mans_exp(x)
print("exp(-x*x) (%.2f) caur summu: %6.2f"%(x,yy))
                                                           

print(" ")
print("                1000                              ")
print("               ______                             ")
print("               \               k      2*k         ")
print("                \          (-1)   * x             ")
print("     exp(-x*x) = >        _________________       ")
print("                /                                 ")
print("               /_____           k!                ")
print("                 k=0                              ")
print("                                                  ")
print("                                                  ")
print("                                             2    ")
print("                                    (-1) * x      ")
print("     Rekurences reizinatajs:      ______________  ")
print("                                                  ")
print("                                         k        ")
# Out:
# exp(-x*x) aprekinasana:
# Lietotāj, lūdzu ievadi skaitli argumentu (x): 0.37
# exp(-x*x) (0.37) =   0.87
# a0 =   1.00 S0 =   1.00
# a499 =  -0.00 S499 =   0.87
# a500 =   0.00 S500 =   0.87
# exp(-x*x) (0.37) caur summu:   0.87
#
#                 1000
#                ______
#                \               k      2*k
#                 \          (-1)   * x
#      exp(-x*x) = >        _________________
#                 /
#                /_____           k!
#                  k=0
#
#
#                                              2
#                                     (-1) * x
#      Rekurences reizinatajs:      ______________
#
#                                          k
